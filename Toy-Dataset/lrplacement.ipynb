# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv("placement.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
plt.scatter(df.cgpa,df.package,color = "red")
plt.xlabel("independent variable\ncgpa")
plt.ylabel("dependent variable\npackage")
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_trian,X_test,y_train,y_test = train_test_split(df[["cgpa"]],df.package, test_size= 0.8,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_trian,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([2.91213984, 4.32802487, 3.15387631, 1.88188204, 3.46468034,
#        3.32078958, 2.74522657, 2.9236511 , 3.04451934, 3.90786386,
#        3.53950353, 2.9236511 , 2.7337153 , 2.62435833, 3.63734925,
#        3.18841009, 3.94239765, 2.88336169, 2.17541918, 3.28050017,
#        4.25895731, 2.8660948 , 1.85885952, 2.28477615, 3.5913042 ,
#        2.11210724, 3.89059697, 2.34808808, 1.55956675, 2.04879531,
#        2.29053178, 3.65461614, 3.47043597, 3.00998555, 2.54953514,
#        2.3711106 , 3.14236505, 3.78699563, 3.13085379, 2.91789547,
#        3.39561278, 2.57255766, 3.59705983, 3.37834589, 2.29053178,
#        3.23445513, 2.29053178, 3.20567698, 2.5610464 , 2.41715564,
#        3.35532337, 1.86461515, 3.18265446, 2.65313648, 2.58406892,
#        3.03876371, 3.66037177, 2.45744506, 2.50924573, 3.48194723,
#        4.13233344, 2.676159  , 2.72220404, 2.35384371, 2.02577279,
#        3.47043597, 2.83156102, 2.76249346, 3.8963526 , 1.87037078,
# ...

# %%
plt.scatter(df.cgpa,df.package,color = "red")
plt.plot(X_test,lr.predict(X_test),color = "black")
plt.xlabel("independent variable\ncgpa")
plt.ylabel("dependent variable\npackage")
plt.show()

# %%
# calculate mse,rootmeansqure,mean absolute ,r2_score

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print(f"mean square error {(np.sum((y_test -lr.predict(X_test))*2))/len(y_test)}")
print(f"mean square error {mean_squared_error(y_test,lr.predict(X_test))}")
print()
# Out:
# mean square error 0.10833241560618867
# mean square error 0.11085592034539729

# %%
print(f"root mean square error {np.sqrt((np.sum((y_test -lr.predict(X_test))*2))/len(y_test))}")
print(f"mean square error {np.sqrt(mean_squared_error(y_test,lr.predict(X_test)))}")
print()
# Out:
# root mean square error 0.32913890017162767
# mean square error 0.3329503271441512

# %%
# mean absolute error 
print(f"mean absolute error {mean_absolute_error(y_test,lr.predict(X_test))}")
# Out:
# mean absolute error 0.2708176687319257

# %%
# r2 score 
print(f"r2 score{r2_score(y_test , lr.predict(X_test))}")
# Out:
# r2 score0.7764063673475987

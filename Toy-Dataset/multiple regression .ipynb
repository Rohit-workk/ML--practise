# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from sklearn.datasets import make_regression
x,y = make_regression(n_samples=100,n_features=5,n_targets=1,noise=20)

# %%
# make it a dataframe 
df = pd.DataFrame({
    "col1":x[:,0],
    "col2":x[:,1], 
    "col3":x[:,3],
    "col4":x[:,4], 
    "col5":x[:,2],
    "target":y
})

# %%
df
# Out:
#         col1      col2      col3      col4      col5     target
# 0  -0.339079 -1.225050  1.317300  2.326889 -2.189842  24.481736
# 1  -0.002924  0.981068 -0.231138  2.203811  0.554950  59.029072
# 2   0.459041  0.657538 -0.062086 -0.972985 -0.376405  37.488119
# 3   0.001544 -0.545267 -0.630103 -0.023274  0.969510  15.326604
# 4   0.421466  1.343968  1.689377 -0.670649  0.117853  56.141840
# ..       ...       ...       ...       ...       ...        ...
# 95  0.543043 -1.112210 -0.292049 -0.212308 -0.134119  -9.821132
# 96  0.154719  0.749885  0.187551  1.507176 -0.245676  19.565770
# 97 -1.166327 -0.144205  0.193128  0.574801 -1.237598 -46.018013
# 98  0.282145 -0.216828 -1.119981  1.520959  0.632040  31.926912
# 99 -1.645968  1.129695  1.627391 -0.444952  0.056116 -97.208377
#
# [100 rows x 6 columns]

# %%
x.shape
# Out:
# (100, 5)

# %%
# lets split our datatset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop(columns="target"),df['target'],test_size=0.2,random_state=2)
x_train
# Out:
#         col1      col2      col3      col4      col5
# 35 -0.771912 -0.696449  0.881655 -0.647610  1.024592
# 11  0.080812  2.162608 -0.062473  0.869128  0.444090
# 84  0.654988 -0.711247 -1.064017  0.486116  0.092544
# 44  1.026726 -0.758310  0.172249  1.002917 -0.130414
# 73 -0.481841  1.449308 -0.862509 -0.460041  0.177606
# ..       ...       ...       ...       ...       ...
# 43  1.619296 -0.298904 -0.590981  1.495062  0.553805
# 22 -0.187934  1.236834  0.250181 -0.788956 -1.003779
# 72  1.489873  0.363529 -0.160330  0.128364 -0.534870
# 15  0.102822 -1.516720 -1.075419 -1.813761  2.084434
# 40 -1.610012  0.074092  1.811042  0.321642  1.701470
#
# [80 rows x 5 columns]

# %%
# now lets train our model 
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("coef  ",lr.intercept_)
print("intercept means b1,b2,b3,b4 ",lr.coef_)
# Out:
# coef   1.2174444224481367
# intercept means b1,b2,b3,b4  [67.38444459 17.80733945 14.78182312 11.20093444  6.50497988]

# %%
# now predict values 
pred_val = lr.predict(x_test)

# %%
# metrices for our multiple linear regression model 
from sklearn.metrics import mean_absolute_error,r2_score
print("mean absolute eror ",mean_absolute_error(y_test,pred_val))
print("r2 score ",r2_score(y_test,pred_val))
# Out:
# mean absolute eror  20.460218849633584
# r2 score  0.829204321794285

# %% [markdown]
# ## ridge regression

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha=5)

# %%
rr.fit(x_train,y_train)
# Out:
# Ridge(alpha=5)

# %%
# intercept and coef with rr
print("slope is ",rr.intercept_)
print("b1,b2,b3,b4,b5",rr.coef_)
# Out:
# slope is  1.1001409235584825
# b1,b2,b3,b4,b5 [62.81955558 16.99945631 13.70737646 11.10069678  5.32193947]

# %%
# with linear model 
print("coef  ",lr.intercept_)
print("intercept means b1,b2,b3,b4 ",lr.coef_)
# Out:
# coef   1.2174444224481367
# intercept means b1,b2,b3,b4  [67.38444459 17.80733945 14.78182312 11.20093444  6.50497988]

# %% [markdown]
# # now metrices comparsion

# %%
print("r2 score for lr ",r2_score(y_test,lr.predict(x_test)))
print("r2score for rr",r2_score(y_test,rr.predict(x_test)))
# Out:
# r2 score for lr  0.829204321794285
# r2score for rr 0.8275537177751126

# %% [markdown]
# # generate a random daataset and perfrom multiple linear regression

# %%
# generate a random daataset and perfrom multiple linear regression 
fea1 = np.random.rand(100)*2
fea2 = np.random.randn(100)*20
fea3 = np.random.rand(100)+25
targett = (fea1*2) + (fea2*2)+fea3 + np.random.rand(100)*3

# %%
# now convert it to a dataframe
df1 = pd.DataFrame({
    "fea1":fea1,
    "fea2":fea2, 
    "fea3":fea3,
    "targett":targett
})

# %%
df
# Out:
#         col1      col2      col3      col4      col5     target
# 0  -0.339079 -1.225050  1.317300  2.326889 -2.189842  24.481736
# 1  -0.002924  0.981068 -0.231138  2.203811  0.554950  59.029072
# 2   0.459041  0.657538 -0.062086 -0.972985 -0.376405  37.488119
# 3   0.001544 -0.545267 -0.630103 -0.023274  0.969510  15.326604
# 4   0.421466  1.343968  1.689377 -0.670649  0.117853  56.141840
# ..       ...       ...       ...       ...       ...        ...
# 95  0.543043 -1.112210 -0.292049 -0.212308 -0.134119  -9.821132
# 96  0.154719  0.749885  0.187551  1.507176 -0.245676  19.565770
# 97 -1.166327 -0.144205  0.193128  0.574801 -1.237598 -46.018013
# 98  0.282145 -0.216828 -1.119981  1.520959  0.632040  31.926912
# 99 -1.645968  1.129695  1.627391 -0.444952  0.056116 -97.208377
#
# [100 rows x 6 columns]

# %%
# train_test split 
xtrain,xtest,ytrain,ytest = train_test_split(df1.drop(columns="targett"),df1['targett'])

# %%
# now fir our model 
lr1 = LinearRegression()
lr1.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# train our redge regrssion 
rr1 = Ridge()

# %%
rr1.fit(xtrain,ytrain)
# Out:
# Ridge()

# %%
# comparsion of r2 score of both models 
print("r2 score for mulple regresion model ",r2_score(ytest,lr1.predict(xtest)))
print("r2score for ridge model ",r2_score(ytest,rr1.predict(xtest)))
# Out:
# r2 score for mulple regresion model  0.9995472233342595
# r2score for ridge model  0.9995516469765412

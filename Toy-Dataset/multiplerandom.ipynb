# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from sklearn.datasets import make_regression

# %%
x,y = make_regression(n_features=2,n_targets=1,noise=20,n_samples=100)

# %%
df = pd.DataFrame({
    "col1":x[:,0],
    "col2":x[:,1],
    "target":y
})

# %%
df
# Out:
#         col1      col2      target
# 0   0.726196  0.986689  174.994549
# 1  -0.325849  1.114640   86.890917
# 2  -0.168447 -0.561133  -64.941686
# 3   0.598670 -0.313414   18.579409
# 4  -0.124424 -0.455171  -74.705314
# ..       ...       ...         ...
# 95  0.978556  0.136528   81.274777
# 96 -0.490957 -0.380638  -64.100575
# 97  0.599833  0.214805   75.382815
# 98  0.936573 -0.610476   19.856322
# 99  1.059599 -1.870758  -91.054326
#
# [100 rows x 3 columns]

# %%
df.describe()
# Out:
#              col1        col2      target
# count  100.000000  100.000000  100.000000
# mean     0.110074    0.215511   30.161989
# std      0.934361    0.951367  105.797604
# min     -2.589311   -2.363376 -222.744077
# 25%     -0.493235   -0.440750  -41.186712
# 50%      0.239721    0.292603   27.070913
# 75%      0.815419    0.788810  112.834751
# max      2.363268    3.117684  235.061808

# %%
#  lets perform multiple regression 
# train test split 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df[["col1","col2"]],df[["target"]],test_size=0.2,random_state=1)
x_train
# Out:
#         col1      col2
# 2  -0.168447 -0.561133
# 73 -0.328981  0.604973
# 97  0.599833  0.214805
# 62 -2.469510  1.566434
# 19  0.360140  0.212120
# ..       ...       ...
# 75  0.022466  0.533143
# 9   0.344384  0.739725
# 72  0.476668  1.356567
# 12  1.850117  0.398561
# 37  0.080114  0.631720
#
# [80 rows x 2 columns]

# %%
# making of object
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
# training of model 
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("slopes for differt line",lr.coef_)
# Out:
# slopes for differt line [[72.29376584 99.37962474]]

# %%
print("intercept for  line ",lr.intercept_)
# Out:
# intercept for  line  [-0.48522862]

# %%
pred_y = lr.predict(x_test)

# %%
# check our model metrices noise 40
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
print("mean squre error ",mean_squared_error(y_test,pred_y))
print("root mean squre error ",np.sqrt(mean_squared_error(y_test,pred_y)))
print("mean absolute error",mean_absolute_error(y_test,pred_y))
print("r2 score",r2_score(y_test,pred_y))
# Out:
# mean squre error  841.3274242333624
# root mean squre error  29.00564469604774
# mean absolute error 20.827551211569503
# r2 score 0.7767919637717642

# %%
# check our model metrices noise 40
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
print("mean squre error ",mean_squared_error(y_test,pred_y))
print("root mean squre error ",np.sqrt(mean_squared_error(y_test,pred_y)))
print("mean absolute error",mean_absolute_error(y_test,pred_y))
print("r2 score",r2_score(y_test,pred_y))
# Out:
# mean squre error  242.33782056996097
# root mean squre error  15.567203363801765
# mean absolute error 11.488852694270275
# r2 score 0.9729088062240873

# %%
# check our model metrices noise 60
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
print("mean squre error ",mean_squared_error(y_test,pred_y))
print("root mean squre error ",np.sqrt(mean_squared_error(y_test,pred_y)))
print("mean absolute error",mean_absolute_error(y_test,pred_y))
print("r2 score",r2_score(y_test,pred_y))
# Out:
# mean squre error  1952.910487482262
# root mean squre error  44.191746825422754
# mean absolute error 35.4104833274692
# r2 score 0.2431444497329437

# %%
# check our model metrices noise 40 data 1000
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
print("mean squre error ",mean_squared_error(y_test,pred_y))
print("root mean squre error ",np.sqrt(mean_squared_error(y_test,pred_y)))
print("mean absolute error",mean_absolute_error(y_test,pred_y))
print("r2 score",r2_score(y_test,pred_y))
# Out:
# mean squre error  1613.2890147740245
# root mean squre error  40.16576919186317
# mean absolute error 31.53455040413418
# r2 score 0.5716579687183834

# %%
# check our model metrices noise 40 data 10000
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
print("mean squre error ",mean_squared_error(y_test,pred_y))
print("root mean squre error ",np.sqrt(mean_squared_error(y_test,pred_y)))
print("mean absolute error",mean_absolute_error(y_test,pred_y))
print("r2 score",r2_score(y_test,pred_y))
# Out:
# mean squre error  1512.6861012915504
# root mean squre error  38.89326550048929
# mean absolute error 31.203062292753437
# r2 score 0.8727995786599647

# %% [raw]
# class gd():
#     def __init__(self,lr = 0.01,epoch = 100):
#         self.epoch = epoch
#         self.lr = lr
#         self.intercpt = None
#         self.coef = None
#
#     def fit(self,xtrain,ytrain):
#         # initilize the intercept
#         self.intercpt = 0
#         self.coef = np.ones(xtrain.shape[1])
#
#         for i in range(self.epoch):
#             yhat = np.dot(xtrain,self.coef) +self.intercpt
#             intercpt_der = -2*(np.mean(ytrain-yhat))
#             self.intercpt = self.intercpt + self.lr*intercpt_der
#
#
#             coef_der = (-2*np.dot((ytrain-yhat),xtrain))/xtrain.shape[1]
#             self.coef = self.coef * self.lr * coef_der
#
#         return (self.intercpt,self.coef)
#
#     def predict(self,xtest):
#         return(np.dot(xtest,self.coef)+self.intercpt)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28996\2439194895.py in ?()
#       1 ourmodel = gd()
# ----> 2 ourmodel.fit(xtrain=x_train,ytrain=y_train)
#
# ~\AppData\Local\Temp\ipykernel_28996\2012203486.py in ?(self, xtrain, ytrain)
#      11         self.coef = np.ones(xtrain.shape[1])
#      12
#      13         for i in range(self.epoch):
#      14             yhat = np.dot(xtrain,self.coef) +self.intercpt
# ---> 15             intercpt_der = -2*(np.mean(ytrain-yhat))
#      16             self.intercpt = self.intercpt + self.lr*intercpt_der
#      17
#      18
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# ...

# %% [raw]
# class gd:
#     def __init__ (self,learningrate = 0.00001,epoch = 100):
#         self.ep = epoch
#         self.lr = learningrate
#         self.coef = None
#         self.intercept = None
#
#     def fit(self,x_train,y_train):
#         # initilize intercept(Bo)
#         self.intercept = 0
#         # initilize the coef
#         self.coef = np.ones(x_train.shape[1])
#
#         # now loop for number of epoch
#         for i in range(self.ep):
#             # now gd formula for intercept
#             y_cap = np.dot(x_train,self.coef)+ self.intercept
#             intercept_derivative = -2*np.mean(y_train - y_cap)
#             self.intercept = self.intercept + self.lr*(intercept_derivative)
#
#             #  now gd formula for coef
#
#             coef_derivative = (-2*(np.dot((y_train - y_cap),x_train)))/x_train.shape[1]
#             self.coef = self.coef + (self.lr*coef_derivative)
#
#         return (self.intercept,self.coef)
#
#
#     def predict(self,x_test):
#
#         return (np.dot(x_test,self.coef)+ self.intercept)

# %%
ourmodel = gd()
ourmodel.fit(x_train=x_train,y_train=y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28996\3239016433.py in ?()
#       1 ourmodel = gd()
# ----> 2 ourmodel.fit(x_train=x_train,y_train=y_train)
#
# ~\AppData\Local\Temp\ipykernel_28996\1271361299.py in ?(self, x_train, y_train)
#      14         # now loop for number of epoch
#      15         for i in range(self.ep):
#      16             # now gd formula for intercept
#      17             y_cap = np.dot(x_train,self.coef)+ self.intercept
# ---> 18             intercept_derivative = -2*np.mean(y_train - y_cap)
#      19             self.intercept = self.intercept + self.lr*(intercept_derivative)
#      20
#      21             #  now gd formula for coef
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
# ...

# %%
class gd:
    def __init__(self, learningrate=0.00001, epoch=100):
        self.ep = epoch
        self.lr = learningrate
        self.coef = None
        self.intercept = None

    def fit(self, x_train, y_train):
        # initialize intercept (B0)
        self.intercept = 0
        # initialize coef
        self.coef = np.ones(x_train.shape[1])

        # loop for number of epochs
        for i in range(self.ep):
            # prediction
            y_cap = np.dot(x_train, self.coef) + self.intercept

            # gradient for intercept
            intercept_derivative = -2 * np.mean(y_train - y_cap)
            self.intercept = self.intercept + self.lr * intercept_derivative

            # gradient for coef
            coef_derivative = (-2 * np.dot(x_train.T, (y_train - y_cap))) / x_train.shape[0]
            self.coef = self.coef + (self.lr * coef_derivative)

        return (self.intercept, self.coef)

    def predict(self, x_test):
        return np.dot(x_test, self.coef) + self.intercept

# %%
# training
ourmodel = gd()
ourmodel.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28996\1428423635.py in ?()
#       1 # training
#       2 ourmodel = gd()
# ----> 3 ourmodel.fit(x_train, y_train)
#
# ~\AppData\Local\Temp\ipykernel_28996\4023178565.py in ?(self, x_train, y_train)
#      16             # prediction
#      17             y_cap = np.dot(x_train, self.coef) + self.intercept
#      18
#      19             # gradient for intercept
# ---> 20             intercept_derivative = -2 * np.mean(y_train - y_cap)
#      21             self.intercept = self.intercept + self.lr * intercept_derivative
#      22
#      23             # gradient for coef
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ...

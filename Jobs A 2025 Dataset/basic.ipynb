# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/jobs-a-2025-dataset/dfall_clean.csv

# %%
df =pd.read_csv("/kaggle/input/jobs-a-2025-dataset/dfall_clean.csv")
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#               id                                              title  \
# 0     5410474609                              Mechanical Pipefitter
# 1     5381519011  International Trade Policy Editor [Startup Pol...
# 2     5389371380                                   Domestic Cleaner
# 3     5403097985                       Early Years BABY Room Leader
# 4     5400306117                           Senior Back-End Engineer
# ...          ...                                                ...
# 3995  5416682608                 Technicien SAV 80-100% CDI (H/F/D)
# 3996  5415370352  German Speaking Support for Social Media - Ins...
# 3997  5285834665     Konstrukteur EFZ (w/m) Lehrabgänger willkommen
# 3998  5285834666  Dachdecker EFZ oder EBA (Lehrabgänger willkommen)
# 3999  5414033250                           European Patent Attorney
#
#                          company_name                 category_label  \
# 0                          Dodd Group      Trade & Construction Jobs
# 1                     Applio Ventures                  Graduate Jobs
# 2              Maid2Clean Suffolk Ltd  Domestic help & Cleaning Jobs
# 3             Jesters Childcare Essex                  Teaching Jobs
# 4                    Eligible Limited                        IT Jobs
# ...                               ...                            ...
# 3995                           Adecco    Sonstige/Allgemeine Stellen
# 3996  Patrique Mercier Recruitment JP    Sonstige/Allgemeine Stellen
# 3997                    DAS PERSONAL.       Stellen aus Handel & Bau
# 3998                    DAS PERSONAL.       Stellen aus Handel & Bau
# 3999         Syngenta Crop Protection                        Unknown
#
#                      category_tag         country         location_display  \
# 0         trade-construction-jobs  United Kingdom     King's Lynn, Norfolk
# 1                   graduate-jobs  United Kingdom               London, UK
# 2     domestic-help-cleaning-jobs  United Kingdom            Diss, Norfolk
# 3                   teaching-jobs  United Kingdom                       UK
# 4                         it-jobs  United Kingdom                       UK
# ...                           ...             ...                      ...
# 3995           other-general-jobs     Switzerland                  Schweiz
# 3996           other-general-jobs     Switzerland                  Schweiz
# 3997      trade-construction-jobs     Switzerland  Martigny, Kanton Wallis
# 3998      trade-construction-jobs     Switzerland                  Schweiz
# 3999                      unknown     Switzerland       Basel, Basel-Stadt
#
#                                           location_area   latitude  longitude  \
# 0          UK > Eastern England > Norfolk > King's Lynn  52.751999   0.395357
# 1                                           UK > London        NaN        NaN
# 2                 UK > Eastern England > Norfolk > Diss  52.377602   1.106380
# 3                                                    UK        NaN        NaN
# 4                                                    UK        NaN        NaN
# ...                                                 ...        ...        ...
# 3995                                            Schweiz        NaN        NaN
# 3996                                            Schweiz        NaN        NaN
# 3997                 Schweiz > Kanton Wallis > Martigny  46.269920   7.153290
# 3998                                            Schweiz        NaN        NaN
# 3999  Schweiz > Kanton Basel-Stadt > Basel-Stadt > B...  47.555755   7.588766
#
#      contract_type contract_time  salary_min  salary_max  salary_mid  \
# 0        permanent     full_time    40518.74    40518.74    40518.74
# 1        permanent     full_time    64000.00    64000.00    64000.00
# 2        permanent     part_time       13.00       13.00       13.00
# 3        permanent     full_time    26707.00    29494.00    28100.50
# 4        permanent     full_time    80000.00         NaN    80000.00
# ...            ...           ...         ...         ...         ...
# 3995           NaN           NaN         NaN         NaN         NaN
# 3996           NaN     full_time       20.00       23.00       21.50
# 3997           NaN           NaN         NaN         NaN         NaN
# 3998           NaN           NaN         NaN         NaN         NaN
# 3999           NaN           NaN         NaN         NaN         NaN
#
#       salary_is_predicted                 created_dt created_date  \
# 0                       1  2025-09-22 09:28:13+00:00   2025-09-22
# 1                       0  2025-09-03 21:20:59+00:00   2025-09-03
# 2                       0  2025-09-08 15:49:25+00:00   2025-09-08
# 3                       0  2025-09-17 15:00:12+00:00   2025-09-17
# 4                       0  2025-09-15 17:51:23+00:00   2025-09-15
# ...                   ...                        ...          ...
# 3995                    0  2025-09-27 02:26:28+00:00   2025-09-27
# 3996                    0  2025-09-26 15:24:32+00:00   2025-09-26
# 3997                    0  2025-07-04 22:56:55+00:00   2025-07-04
# 3998                    0  2025-07-04 22:56:55+00:00   2025-07-04
# 3999                    0  2025-09-24 20:31:21+00:00   2025-09-24
#
#                                            redirect_url  \
# 0     https://www.adzuna.co.uk/jobs/details/54104746...
# 1     https://www.adzuna.co.uk/jobs/details/53815190...
# 2     https://www.adzuna.co.uk/jobs/details/53893713...
# 3     https://www.adzuna.co.uk/jobs/details/54030979...
# 4     https://www.adzuna.co.uk/jobs/details/54003061...
# ...                                                 ...
# 3995  https://www.adzuna.ch/details/5416682608?utm_m...
# 3996  https://www.adzuna.ch/details/5415370352?utm_m...
# 3997  https://www.adzuna.ch/details/5285834665?utm_m...
# 3998  https://www.adzuna.ch/details/5285834666?utm_m...
# 3999  https://www.adzuna.ch/details/5414033250?utm_m...
#
#                                                   adref
# 0     eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQxMDQ3NDYwOSIsI...
# 1     eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTM4MTUxOTAxMSIsI...
# 2     eyJhbGciOiJIUzI1NiJ9.eyJzIjoiRWtwZjc5cWI4QkdZM...
# 3     eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQwMzA5Nzk4NSIsI...
# 4     eyJhbGciOiJIUzI1NiJ9.eyJzIjoiRWtwZjc5cWI4QkdZM...
# ...                                                 ...
# 3995  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQxNjY4MjYwOCIsI...
# 3996  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiNkxnSGRkdWI4Qkdad...
# 3997  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTI4NTgzNDY2NSIsI...
# 3998  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiNkxnSGRkdWI4Qkdad...
# 3999  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQxNDAzMzI1MCIsI...
#
# [4000 rows x 20 columns]

# %%
# lets understand the disrtibution and basic knowledge of dataset
print(f"Shape of dataset {df.shape}")
print("==="*30)
print(f"Feature name are {list(df.columns)}")
print("==="*30)
print(f"datatypes of each feature \n {df.dtypes}")
print("==="*30)
print(f"numerical datatypes features are {df.select_dtypes(include = np.number).columns.tolist()}")
print("==="*30)
print(f"object datatypes feature are {df.select_dtypes(include = 'O').columns.tolist()}")
print("==="*30)
print(f"Information of dataset {df.info()}")
print("==="*30)
print(f"describtion of numerical columns \n {df.describe()}")
print("==="*30)
print(f"descrption for non integer columne \n{df.describe(include = 'O')}")
print("==="*30)
# Out:
# Shape of dataset (4000, 20)
# ==========================================================================================
# Feature name are ['id', 'title', 'company_name', 'category_label', 'category_tag', 'country', 'location_display', 'location_area', 'latitude', 'longitude', 'contract_type', 'contract_time', 'salary_min', 'salary_max', 'salary_mid', 'salary_is_predicted', 'created_dt', 'created_date', 'redirect_url', 'adref']
# ==========================================================================================
# datatypes of each feature
#  id                       int64
# title                   object
# company_name            object
# category_label          object
# category_tag            object
# country                 object
# location_display        object
# location_area           object
# latitude               float64
# longitude              float64
# contract_type           object
# contract_time           object
# salary_min             float64
# salary_max             float64
# salary_mid             float64
# salary_is_predicted      int64
# created_dt              object
# created_date            object
# redirect_url            object
# adref                   object
# dtype: object
# ==========================================================================================
# numerical datatypes features are ['id', 'latitude', 'longitude', 'salary_min', 'salary_max', 'salary_mid', 'salary_is_predicted']
# ==========================================================================================
# object datatypes feature are ['title', 'company_name', 'category_label', 'category_tag', 'country', 'location_display', 'location_area', 'contract_type', 'contract_time', 'created_dt', 'created_date', 'redirect_url', 'adref']
# ==========================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   4000 non-null   int64
#  1   title                4000 non-null   object
#  2   company_name         3786 non-null   object
#  3   category_label       4000 non-null   object
#  4   category_tag         4000 non-null   object
#  5   country              4000 non-null   object
#  6   location_display     4000 non-null   object
#  7   location_area        4000 non-null   object
#  8   latitude             3257 non-null   float64
#  9   longitude            3257 non-null   float64
#  10  contract_type        846 non-null    object
#  11  contract_time        985 non-null    object
#  12  salary_min           1544 non-null   float64
#  13  salary_max           1535 non-null   float64
#  14  salary_mid           1544 non-null   float64
#  15  salary_is_predicted  4000 non-null   int64
#  16  created_dt           4000 non-null   object
#  17  created_date         4000 non-null   object
#  18  redirect_url         4000 non-null   object
#  19  adref                4000 non-null   object
# dtypes: float64(5), int64(2), object(13)
# memory usage: 625.1+ KB
# Information of dataset None
# ==========================================================================================
# describtion of numerical columns
#                   id     latitude    longitude    salary_min    salary_max  \
# count  4.000000e+03  3257.000000  3257.000000  1.544000e+03  1.535000e+03
# mean   5.316432e+09    46.967893    -8.814865  4.549448e+04  5.627804e+04
# std    2.036443e+08     5.306513    34.321400  9.365883e+04  2.223390e+05
# min    2.983960e+09    18.081052  -157.739444  0.000000e+00  1.000000e+00
# 25%    5.322522e+09    43.934213    -1.499100  2.200000e+04  2.543800e+04
# 50%    5.389136e+09    47.424029     4.919448  3.461617e+04  4.000000e+04
# 75%    5.406462e+09    51.503378     8.518157  5.530624e+04  6.156134e+04
# max    5.418264e+09    57.579973    18.227159  2.000000e+06  5.000000e+06
#
#          salary_mid  salary_is_predicted
# count  1.544000e+03          4000.000000
# mean   5.080285e+04             0.139750
# std    1.567656e+05             0.346771
# min    1.000000e+00             0.000000
# 25%    2.405000e+04             0.000000
# 50%    3.750000e+04             0.000000
# 75%    5.750000e+04             0.000000
# max    3.500000e+06             1.000000
# ==========================================================================================
# descrption for non integer columne
#                                   title company_name category_label  \
# count                              4000         3786           4000
# unique                             3291         1224            121
# top     INFIRMIER ANESTHÉSISTE DE (F/H)       Adecco        Unknown
# freq                                 87          208           1108
#
#        category_tag         country location_display location_area  \
# count          4000            4000             4000          4000
# unique           30               8             2162          2162
# top         unknown  United Kingdom           España        España
# freq           1108             500              295           295
#
#        contract_type contract_time                 created_dt created_date  \
# count            846           985                       4000         4000
# unique             2             2                       2899          360
# top         contract     full_time  2025-07-10 15:31:27+00:00   2025-09-26
# freq             560           800                         21          323
#
#                                              redirect_url  \
# count                                                4000
# unique                                               3986
# top     https://www.adzuna.es/details/5391918840?utm_m...
# freq                                                    2
#
#                                                     adref
# count                                                4000
# unique                                               4000
# top     eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQxMDQ3NDYwOSIsI...
# freq                                                    1
# ==========================================================================================

# %%
# lets cehck for null values
for col in df.columns:
    print("=="*40)
    print(f"for column {col}")
    print(f"   number of null values :{df[col].isna().sum()}")
    print(f"   percentage of null values :{df[col].isna().mean()*100:.2f} %")
# Out:
# ================================================================================
# for column id
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column title
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column company_name
#    number of null values :214
#    percentage of null values :5.35 %
# ================================================================================
# for column category_label
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column category_tag
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column country
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column location_display
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column location_area
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column latitude
#    number of null values :743
#    percentage of null values :18.57 %
# ================================================================================
# for column longitude
#    number of null values :743
#    percentage of null values :18.57 %
# ================================================================================
# for column contract_type
#    number of null values :3154
#    percentage of null values :78.85 %
# ================================================================================
# for column contract_time
#    number of null values :3015
#    percentage of null values :75.38 %
# ================================================================================
# for column salary_min
#    number of null values :2456
#    percentage of null values :61.40 %
# ================================================================================
# for column salary_max
#    number of null values :2465
#    percentage of null values :61.62 %
# ================================================================================
# for column salary_mid
#    number of null values :2456
#    percentage of null values :61.40 %
# ================================================================================
# for column salary_is_predicted
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column created_dt
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column created_date
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column redirect_url
#    number of null values :0
#    percentage of null values :0.00 %
# ================================================================================
# for column adref
#    number of null values :0
#    percentage of null values :0.00 %

# %%
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#               id                                              title  \
# 0     5410474609                              Mechanical Pipefitter
# 1     5381519011  International Trade Policy Editor [Startup Pol...
# 2     5389371380                                   Domestic Cleaner
# 3     5403097985                       Early Years BABY Room Leader
# 4     5400306117                           Senior Back-End Engineer
# ...          ...                                                ...
# 3995  5416682608                 Technicien SAV 80-100% CDI (H/F/D)
# 3996  5415370352  German Speaking Support for Social Media - Ins...
# 3997  5285834665     Konstrukteur EFZ (w/m) Lehrabgänger willkommen
# 3998  5285834666  Dachdecker EFZ oder EBA (Lehrabgänger willkommen)
# 3999  5414033250                           European Patent Attorney
#
#                          company_name                 category_label  \
# 0                          Dodd Group      Trade & Construction Jobs
# 1                     Applio Ventures                  Graduate Jobs
# 2              Maid2Clean Suffolk Ltd  Domestic help & Cleaning Jobs
# 3             Jesters Childcare Essex                  Teaching Jobs
# 4                    Eligible Limited                        IT Jobs
# ...                               ...                            ...
# 3995                           Adecco    Sonstige/Allgemeine Stellen
# 3996  Patrique Mercier Recruitment JP    Sonstige/Allgemeine Stellen
# 3997                    DAS PERSONAL.       Stellen aus Handel & Bau
# 3998                    DAS PERSONAL.       Stellen aus Handel & Bau
# 3999         Syngenta Crop Protection                        Unknown
#
#                      category_tag         country         location_display  \
# 0         trade-construction-jobs  United Kingdom     King's Lynn, Norfolk
# 1                   graduate-jobs  United Kingdom               London, UK
# 2     domestic-help-cleaning-jobs  United Kingdom            Diss, Norfolk
# 3                   teaching-jobs  United Kingdom                       UK
# 4                         it-jobs  United Kingdom                       UK
# ...                           ...             ...                      ...
# 3995           other-general-jobs     Switzerland                  Schweiz
# 3996           other-general-jobs     Switzerland                  Schweiz
# 3997      trade-construction-jobs     Switzerland  Martigny, Kanton Wallis
# 3998      trade-construction-jobs     Switzerland                  Schweiz
# 3999                      unknown     Switzerland       Basel, Basel-Stadt
#
#                                           location_area   latitude  longitude  \
# 0          UK > Eastern England > Norfolk > King's Lynn  52.751999   0.395357
# 1                                           UK > London        NaN        NaN
# 2                 UK > Eastern England > Norfolk > Diss  52.377602   1.106380
# 3                                                    UK        NaN        NaN
# 4                                                    UK        NaN        NaN
# ...                                                 ...        ...        ...
# 3995                                            Schweiz        NaN        NaN
# 3996                                            Schweiz        NaN        NaN
# 3997                 Schweiz > Kanton Wallis > Martigny  46.269920   7.153290
# 3998                                            Schweiz        NaN        NaN
# 3999  Schweiz > Kanton Basel-Stadt > Basel-Stadt > B...  47.555755   7.588766
#
#      contract_type contract_time  salary_min  salary_max  salary_mid  \
# 0        permanent     full_time    40518.74    40518.74    40518.74
# 1        permanent     full_time    64000.00    64000.00    64000.00
# 2        permanent     part_time       13.00       13.00       13.00
# 3        permanent     full_time    26707.00    29494.00    28100.50
# 4        permanent     full_time    80000.00         NaN    80000.00
# ...            ...           ...         ...         ...         ...
# 3995           NaN           NaN         NaN         NaN         NaN
# 3996           NaN     full_time       20.00       23.00       21.50
# 3997           NaN           NaN         NaN         NaN         NaN
# 3998           NaN           NaN         NaN         NaN         NaN
# 3999           NaN           NaN         NaN         NaN         NaN
#
#       salary_is_predicted                 created_dt created_date  \
# 0                       1  2025-09-22 09:28:13+00:00   2025-09-22
# 1                       0  2025-09-03 21:20:59+00:00   2025-09-03
# 2                       0  2025-09-08 15:49:25+00:00   2025-09-08
# 3                       0  2025-09-17 15:00:12+00:00   2025-09-17
# 4                       0  2025-09-15 17:51:23+00:00   2025-09-15
# ...                   ...                        ...          ...
# 3995                    0  2025-09-27 02:26:28+00:00   2025-09-27
# 3996                    0  2025-09-26 15:24:32+00:00   2025-09-26
# 3997                    0  2025-07-04 22:56:55+00:00   2025-07-04
# 3998                    0  2025-07-04 22:56:55+00:00   2025-07-04
# 3999                    0  2025-09-24 20:31:21+00:00   2025-09-24
#
#                                            redirect_url  \
# 0     https://www.adzuna.co.uk/jobs/details/54104746...
# 1     https://www.adzuna.co.uk/jobs/details/53815190...
# 2     https://www.adzuna.co.uk/jobs/details/53893713...
# 3     https://www.adzuna.co.uk/jobs/details/54030979...
# 4     https://www.adzuna.co.uk/jobs/details/54003061...
# ...                                                 ...
# 3995  https://www.adzuna.ch/details/5416682608?utm_m...
# 3996  https://www.adzuna.ch/details/5415370352?utm_m...
# 3997  https://www.adzuna.ch/details/5285834665?utm_m...
# 3998  https://www.adzuna.ch/details/5285834666?utm_m...
# 3999  https://www.adzuna.ch/details/5414033250?utm_m...
#
#                                                   adref
# 0     eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQxMDQ3NDYwOSIsI...
# 1     eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTM4MTUxOTAxMSIsI...
# 2     eyJhbGciOiJIUzI1NiJ9.eyJzIjoiRWtwZjc5cWI4QkdZM...
# 3     eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQwMzA5Nzk4NSIsI...
# 4     eyJhbGciOiJIUzI1NiJ9.eyJzIjoiRWtwZjc5cWI4QkdZM...
# ...                                                 ...
# 3995  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQxNjY4MjYwOCIsI...
# 3996  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiNkxnSGRkdWI4Qkdad...
# 3997  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTI4NTgzNDY2NSIsI...
# 3998  eyJhbGciOiJIUzI1NiJ9.eyJzIjoiNkxnSGRkdWI4Qkdad...
# 3999  eyJhbGciOiJIUzI1NiJ9.eyJpIjoiNTQxNDAzMzI1MCIsI...
#
# [4000 rows x 20 columns]

# %%
# lets check for unique values in each feature
for col in df.columns:
    print("=="*40)
    print(f"number of unique values in  {col} are {df[col].nunique()}")
# Out:
# ================================================================================
# number of unique values in  id are 3986
# ================================================================================
# number of unique values in  title are 3291
# ================================================================================
# number of unique values in  company_name are 1224
# ================================================================================
# number of unique values in  category_label are 121
# ================================================================================
# number of unique values in  category_tag are 30
# ================================================================================
# number of unique values in  country are 8
# ================================================================================
# number of unique values in  location_display are 2162
# ================================================================================
# number of unique values in  location_area are 2162
# ================================================================================
# number of unique values in  latitude are 2184
# ================================================================================
# number of unique values in  longitude are 2184
# ================================================================================
# number of unique values in  contract_type are 2
# ================================================================================
# number of unique values in  contract_time are 2
# ================================================================================
# number of unique values in  salary_min are 859
# ================================================================================
# number of unique values in  salary_max are 881
# ================================================================================
# number of unique values in  salary_mid are 1006
# ================================================================================
# number of unique values in  salary_is_predicted are 2
# ================================================================================
# number of unique values in  created_dt are 2899
# ================================================================================
# number of unique values in  created_date are 360
# ================================================================================
# number of unique values in  redirect_url are 3986
# ================================================================================
# number of unique values in  adref are 4000
